# %% [markdown]
# ## Data collection

# %% [markdown]
# All Data is Download from https://fred.stlouisfed.org/

# %%
#importing required libraries
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ###### Label:- S&P/Case-Shiller U.S. National Home Price Index: target variable

# %%
#Reading CASE-SHILLER Index into a dataframe
label = pd.read_csv("D:\homeLLC\data\priceindex.csv.csv")
label.head()
# Out:
#          DATE  CSUSHPISA
# 0  2003-09-01    136.294
# 1  2003-10-01    137.531
# 2  2003-11-01    138.794
# 3  2003-12-01    140.179
# 4  2004-01-01    141.646

# %%
#  column renaming. 
label.rename(columns= {'CSUSHPINSA': 'home_price'}, inplace =True)

# %%
label.shape
# Out:
# (241, 2)

# %% [markdown]
# ###### Interest rates

# %% [markdown]
# •	Mortgage Rate (A mortgage rate is the interest rate charged for a home loan.(Percentage))

# %%
#Reading Interest rates into a dataframe
Interest = pd.read_csv("D:\homeLLC\data\FEDFUNDS.csv")
Interest.head(5)
# Out:
#          DATE  FEDFUNDS
# 0  2003-09-01      1.01
# 1  2003-10-01      1.01
# 2  2003-11-01      1.00
# 3  2003-12-01      0.98
# 4  2004-01-01      1.00

# %%
#  column renaming. 
Interest.rename(columns= {'FEDFUNDS': 'Interest'}, inplace =True)

# %%
Interest.shape
# Out:
# (241, 2)

# %% [markdown]
# ###### Unemployment rate

# %% [markdown]
# •	Unemployment Rate (The unemployment rate represents the number of unemployed as a percentage of the labor force. (16 years age or above))

# %%
#Reading Unemployment rate into a dataframe
Unemp_rate = pd.read_csv("D:\\homeLLC\\data\\UNRATENSA.csv")
Unemp_rate.head(5)
# Out:
#          DATE  UNRATENSA
# 0  2003-09-01        5.8
# 1  2003-10-01        5.6
# 2  2003-11-01        5.6
# 3  2003-12-01        5.4
# 4  2004-01-01        6.3

# %%
# column renaming. 
Unemp_rate.rename(columns= {'UNRATENSA': 'Unemp_rate'}, inplace =True)

# %%
Unemp_rate.shape
# Out:
# (241, 2)

# %% [markdown]
# ###### Per Capita GDP

# %% [markdown]
# •	Gross Domestic Product (Featured measure of U.S. output, is the market value of the goods and services produced by labor and property located in the United States.)

# %%
#Reading Per Capita GDP into a dataframe
GDP = pd.read_csv("D:\homeLLC\data\A939RX0Q048SBEA.csv")
GDP.head(5)
# Out:
#          DATE  A939RX0Q048SBEA
# 0  2003-07-01          51512.0
# 1  2003-10-01          51986.0
# 2  2004-01-01          52179.0
# 3  2004-04-01          52469.0
# 4  2004-07-01          52835.0

# %%
# column renaming. 
GDP.rename(columns= {'A939RX0Q048SBEA': 'GDP'}, inplace =True)

# %%
GDP.shape
# Out:
# (81, 2)

# %% [markdown]
# ###### Income

# %% [markdown]
# •	Personal Income (Income that persons receive in return for their provision of labor, land, and capital used in current production and the net current transfer payments that they receive from business and from government.)

# %%
#Reading Income into a dataframe
Income = pd.read_csv("D:\homeLLC\data\DSPIC96.csv")
Income.head(5)
# Out:
#          DATE  DSPIC96
# 0  2003-09-01  10940.8
# 1  2003-10-01  10982.3
# 2  2003-11-01  11048.4
# 3  2003-12-01  11057.2
# 4  2004-01-01  11051.2

# %%
# column renaming. 
Income.rename(columns= {'DSPIC96': 'Income'}, inplace =True)

# %%
Income.shape
# Out:
# (241, 2)

# %% [markdown]
# ###### New Constructed units

# %%
#Reading New Constructed units into a dataframe
Const_units = pd.read_csv("D:\homeLLC\data\COMPUTSA.csv")
Const_units.head(5)
# Out:
#          DATE  COMPUTSA
# 0  2003-09-01    1719.0
# 1  2003-10-01    1728.0
# 2  2003-11-01    1692.0
# 3  2003-12-01    1716.0
# 4  2004-01-01    1709.0

# %%
# column renaming. 
Const_units.rename(columns= {'COMPUTSA': 'Const_units'}, inplace =True)

# %%
Const_units.shape
# Out:
# (241, 2)

# %% [markdown]
# ###### Construction price index

# %% [markdown]
# The index measures changes in cost for production factors in housing construction,

# %%
#Reading Construction price index into a dataframe
Const_price = pd.read_csv("D:\homeLLC\data\WPUSI012011.csv")
Const_price.head(5)
# Out:
#          DATE  WPUSI012011
# 0  2003-09-01        149.0
# 1  2003-10-01        149.6
# 2  2003-11-01        150.2
# 3  2003-12-01        149.7
# 4  2004-01-01        150.0

# %%
# column renaming. 
Const_price.rename(columns= {'WPUSI012011': 'Const_price'}, inplace =True)

# %%
Const_price.shape
# Out:
# (241, 2)

# %% [markdown]
# ###### Housing Subsidies

# %% [markdown]
# A subsidy is a benefit given by the government to groups or individuals, usually in the form of a cash payment or tax reduction.

# %%
#Reading Housing Subsidies (Federal) into a datafram
Subsidies = pd.read_csv("D:\homeLLC\data\L312051A027NBEA.csv")
Subsidies.head(5)
# Out:
#          DATE  L312051A027NBEA
# 0  2003-01-01           25.930
# 1  2004-01-01           27.201
# 2  2005-01-01           27.651
# 3  2006-01-01           28.604
# 4  2007-01-01           29.512

# %%
#column renaming. 
Subsidies.rename(columns= {'L312051A027NBEA': 'Subsidies'}, inplace =True)

# %%
Subsidies.shape
# Out:
# (21, 2)

# %% [markdown]
# ###### Total households

# %%
#Reading Total households into a dataframe
households = pd.read_csv("D:\homeLLC\data\TTLHH.csv")
households.head(5)
# Out:
#          DATE     TTLHH
# 0  2003-01-01  111278.0
# 1  2004-01-01  112000.0
# 2  2005-01-01  113343.0
# 3  2006-01-01  114384.0
# 4  2007-01-01  116011.0

# %%
#column renaming. 
households.rename(columns= {'TTLHH': 'households'}, inplace =True)

# %%
households.shape
# Out:
# (21, 2)

# %% [markdown]
# ###### Median sale price

# %% [markdown]
# (Median Sales Price of Houses Sold for the United States.(US Dollers))

# %%
#Reading Median sale price into a dataframe
sale_price = pd.read_csv("D:\homeLLC\data\MSPUS.csv")
sale_price.head(5)
# Out:
#          DATE     MSPUS
# 0  2003-07-01  191900.0
# 1  2003-10-01  198800.0
# 2  2004-01-01  212700.0
# 3  2004-04-01  217600.0
# 4  2004-07-01  213500.0

# %%
#  column renaming. 
sale_price.rename(columns= {'MSPUS': 'sale_price'}, inplace =True)

# %%
sale_price.shape
# Out:
# (81, 2)

# %% [markdown]
# ###### employmen population

# %% [markdown]
# •	Employment- (Population Ratio (emratio))

# %%
#Reading employmen population ratio into a dataframe
empl_population = pd.read_csv("D:\homeLLC\data\LNU01300000.csv")
empl_population.head(5)
# Out:
#          DATE  LNU01300000
# 0  2003-09-01         65.9
# 1  2003-10-01         66.1
# 2  2003-11-01         66.1
# 3  2003-12-01         65.8
# 4  2004-01-01         65.7

# %%
#column renaming. 
empl_population.rename(columns= {'LNU01300000': 'empl_population'}, inplace =True)

# %%
empl_population.shape
# Out:
# (241, 2)

# %% [markdown]
# ###### population

# %%
#Reading population  into a dataframe
population = pd.read_csv("D:\homeLLC\data\POPTHM.csv")
population.head(5)
# Out:
#          DATE    POPTHM
# 0  2003-09-01  291222.0
# 1  2003-10-01  291463.0
# 2  2003-11-01  291677.0
# 3  2003-12-01  291868.0
# 4  2004-01-01  292046.0

# %%
#column renaming. 
population.rename(columns= {'POPTHM': 'population'}, inplace =True)

# %%
population.shape
# Out:
# (241, 2)

# %% [markdown]
# ###### Consumer Price Index

# %% [markdown]
#  Indicates inflation in housing costs , affecting housing affordability , potentially impacting home prices

# %%
#Reading Consumer Price Index  into a dataframe
CPI = pd.read_csv("D:\homeLLC\data\CPIAUCNS.csv")
CPI.head(5)
# Out:
#          DATE  CPIAUCNS
# 0  2003-09-01     185.2
# 1  2003-10-01     185.0
# 2  2003-11-01     184.5
# 3  2003-12-01     184.3
# 4  2004-01-01     185.2

# %%
# column renaming. 
CPI.rename(columns= {'POPTHM': 'population'}, inplace =True)

# %%
CPI.shape
# Out:
# (241, 2)

# %% [markdown]
# ###### Total Units Authorized in Permit-Issuing Places ratio

# %%
#Reading Total Units Authorized in Permit-Issuing Places ratio into a dataframe
Units_Authoriz = pd.read_csv("D:\homeLLC\data\PERMIT.csv")
Units_Authoriz.head(5)
# Out:
#          DATE  PERMIT
# 0  2003-09-01  1961.0
# 1  2003-10-01  2012.0
# 2  2003-11-01  1918.0
# 3  2003-12-01  1987.0
# 4  2004-01-01  1952.0

# %%
# column renaming. 
Units_Authoriz.rename(columns= {'PERMIT': 'Units_Authoriz'}, inplace =True)

# %%
Units_Authoriz.shape
# Out:
# (241, 2)

# %% [markdown]
# ##### Merging Dataframe

# %%
# Concating dataframes having monthly data to create one dataframe
df = pd.DataFrame()
df_bymonth = [Interest, Unemp_rate, Income, Const_units, Const_price, empl_population,population,Units_Authoriz,label,CPI]
for dataframe in df_bymonth:
    dataframe["DATE"] = pd.to_datetime(dataframe["DATE"])
    dataframe = dataframe.set_index("DATE")
    df = pd.concat([df,dataframe], axis = 1)
print(df.shape)
df.head()
# Out:
# (241, 10)
#             Interest  Unemp_rate   Income  Const_units  Const_price  \
# DATE
# 2003-09-01      1.01         5.8  10940.8       1719.0        149.0
# 2003-10-01      1.01         5.6  10982.3       1728.0        149.6
# 2003-11-01      1.00         5.6  11048.4       1692.0        150.2
# 2003-12-01      0.98         5.4  11057.2       1716.0        149.7
# 2004-01-01      1.00         6.3  11051.2       1709.0        150.0
#
#             empl_population  population  Units_Authoriz  CSUSHPISA  CPIAUCNS
# DATE
# 2003-09-01             65.9    291222.0          1961.0    136.294     185.2
# 2003-10-01             66.1    291463.0          2012.0    137.531     185.0
# 2003-11-01             66.1    291677.0          1918.0    138.794     184.5
# 2003-12-01             65.8    291868.0          1987.0    140.179     184.3
# 2004-01-01             65.7    292046.0          1952.0    141.646     185.2

# %%
# Concating dataframes having quaterly data to create one dataframe
df1 = pd.DataFrame()
df_byquaterly = [sale_price, GDP]
for dataframe in df_byquaterly:
    dataframe["DATE"] = pd.to_datetime(dataframe["DATE"])
    dataframe = dataframe.set_index("DATE")
    df1 = pd.concat([df1,dataframe], axis = 1)
print(df1.shape)
df1.head()
# Out:
# (81, 2)
#             sale_price      GDP
# DATE
# 2003-07-01    191900.0  51512.0
# 2003-10-01    198800.0  51986.0
# 2004-01-01    212700.0  52179.0
# 2004-04-01    217600.0  52469.0
# 2004-07-01    213500.0  52835.0

# %%
# Concating dataframes having annually data to create one dataframe
df2 = pd.DataFrame()
df_byannually = [households, Subsidies]
for dataframe in df_byannually:
    dataframe["DATE"] = pd.to_datetime(dataframe["DATE"])
    dataframe = dataframe.set_index("DATE")
    df2 = pd.concat([df2,dataframe], axis = 1)
print(df2.shape)
df2.head()
# Out:
# (21, 2)
#             households  Subsidies
# DATE
# 2003-01-01    111278.0     25.930
# 2004-01-01    112000.0     27.201
# 2005-01-01    113343.0     27.651
# 2006-01-01    114384.0     28.604
# 2007-01-01    116011.0     29.512

# %%
# Merge DataFrames using 'DATE' as the common column
merged_df = pd.merge(df1, df2, on='DATE', how='outer')

# %%
merged_df
# Out:
#             sale_price      GDP  households  Subsidies
# DATE
# 2003-07-01    191900.0  51512.0         NaN        NaN
# 2003-10-01    198800.0  51986.0         NaN        NaN
# 2004-01-01    212700.0  52179.0    112000.0     27.201
# 2004-04-01    217600.0  52469.0         NaN        NaN
# 2004-07-01    213500.0  52835.0         NaN        NaN
# ...                ...      ...         ...        ...
# 2022-10-01    479500.0  65783.0         NaN        NaN
# 2023-01-01    429000.0  66078.0    131434.0     50.299
# 2023-04-01    418500.0  66341.0         NaN        NaN
# 2023-07-01    431000.0  67083.0         NaN        NaN
# 2003-01-01         NaN      NaN    111278.0     25.930
#
# [82 rows x 4 columns]

# %%
# Merge DataFrames using 'DATE' as the common column
final_df = pd.merge(df, merged_df, on='DATE', how='outer')

# %%
final_df
# Out:
#             Interest  Unemp_rate   Income  Const_units  Const_price  \
# DATE
# 2003-09-01      1.01         5.8  10940.8       1719.0      149.000
# 2003-10-01      1.01         5.6  10982.3       1728.0      149.600
# 2003-11-01      1.00         5.6  11048.4       1692.0      150.200
# 2003-12-01      0.98         5.4  11057.2       1716.0      149.700
# 2004-01-01      1.00         6.3  11051.2       1709.0      150.000
# ...              ...         ...      ...          ...          ...
# 2023-07-01      5.12         3.8  16796.9       1334.0      334.576
# 2023-08-01      5.33         3.9  16799.7       1370.0      333.980
# 2023-09-01      5.33         3.6  16804.8       1478.0      332.224
# 2003-07-01       NaN         NaN      NaN          NaN          NaN
# 2003-01-01       NaN         NaN      NaN          NaN          NaN
#
#             empl_population  population  Units_Authoriz  CSUSHPISA  CPIAUCNS  \
# DATE
# 2003-09-01             65.9    291222.0          1961.0    136.294   185.200
# 2003-10-01             66.1    291463.0          2012.0    137.531   185.000
# 2003-11-01             66.1    291677.0          1918.0    138.794   184.500
# 2003-12-01             65.8    291868.0          1987.0    140.179   184.300
# 2004-01-01             65.7    292046.0          1952.0    141.646   185.200
# ...                     ...         ...             ...        ...       ...
# 2023-07-01             63.1    335329.0          1443.0    306.767   305.691
# 2023-08-01             62.9    335501.0          1541.0    309.155   307.026
# 2023-09-01             62.7    335675.0          1471.0    311.175   307.789
# 2003-07-01              NaN         NaN             NaN        NaN       NaN
# 2003-01-01              NaN         NaN             NaN        NaN       NaN
#
#             sale_price      GDP  households  Subsidies
# DATE
# 2003-09-01         NaN      NaN         NaN        NaN
# 2003-10-01    198800.0  51986.0         NaN        NaN
# 2003-11-01         NaN      NaN         NaN        NaN
# 2003-12-01         NaN      NaN         NaN        NaN
# 2004-01-01    212700.0  52179.0    112000.0     27.201
# ...                ...      ...         ...        ...
# 2023-07-01    431000.0  67083.0         NaN        NaN
# 2023-08-01         NaN      NaN         NaN        NaN
# 2023-09-01         NaN      NaN         NaN        NaN
# 2003-07-01    191900.0  51512.0         NaN        NaN
# 2003-01-01         NaN      NaN    111278.0     25.930
#
# [243 rows x 14 columns]

# %%
df=final_df[:-2]

# %%
df.shape
# Out:
# (241, 14)

# %%
# Reset the index to default integer index
df_reset = df.reset_index(drop=False)

# %%
# resetting of date column
df_reset['DATE'] = pd.to_datetime(df_reset['DATE'])

df_reset['Month'] = df_reset['DATE'].dt.month

df_reset['Year'] = df_reset['DATE'].dt.year

df_reset['Day'] = df_reset['DATE'].dt.day

df_reset.drop('DATE',axis=1,inplace=True)

# %%
df = df_reset

# %%
df.shape
# Out:
# (241, 17)

# %% [markdown]
# ##### EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Interest         241 non-null    float64
#  1   Unemp_rate       241 non-null    float64
#  2   Income           241 non-null    float64
#  3   Const_units      241 non-null    float64
#  4   Const_price      241 non-null    float64
#  5   empl_population  241 non-null    float64
#  6   population       241 non-null    float64
#  7   Units_Authoriz   241 non-null    float64
#  8   CSUSHPISA        241 non-null    float64
#  9   CPIAUCNS         241 non-null    float64
#  10  sale_price       80 non-null     float64
#  11  GDP              80 non-null     float64
#  12  households       20 non-null     float64
#  13  Subsidies        20 non-null     float64
#  14  Month            241 non-null    int64
#  15  Year             241 non-null    int64
#  16  Day              241 non-null    int64
# dtypes: float64(14), int64(3)
# memory usage: 32.1 KB

# %% [markdown]
# All Features and target cantain only float type dataset

# %%
df.isnull().sum()
# Out:
# Interest             0
# Unemp_rate           0
# Income               0
# Const_units          0
# Const_price          0
# empl_population      0
# population           0
# Units_Authoriz       0
# CSUSHPISA            0
# CPIAUCNS             0
# sale_price         161
# GDP                161
# households         221
# Subsidies          221
# Month                0
# Year                 0
# Day                  0
# dtype: int64

# %% [markdown]
# Observation: There are some nan values here, but the data on nan values is only available on a quarterly or annual basis, therefore we're populating the nan values with the most recent available data.

# %%
# filling Nan values
df['sale_price'] = df['sale_price'].ffill()
df['GDP'] = df['GDP'].ffill()
df['households'] = df['households'].ffill()
df['Subsidies'] = df['Subsidies'].ffill()

# %%
# Fill missing values with data available
df['Subsidies'].fillna('25.93', inplace=True)
df['households'].fillna('111278.0', inplace=True)
df['GDP'].fillna('51512', inplace=True)
df['sale_price'].fillna('19750', inplace=True)

# %%
# again checking for null values
df.isnull().sum()
# Out:
# Interest           0
# Unemp_rate         0
# Income             0
# Const_units        0
# Const_price        0
# empl_population    0
# population         0
# Units_Authoriz     0
# CSUSHPISA          0
# CPIAUCNS           0
# sale_price         0
# GDP                0
# households         0
# Subsidies          0
# Month              0
# Year               0
# Day                0
# dtype: int64

# %%
#importing required libraries
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#visualised for NaN values
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Null values was completly removed

# %%
# checking for white space
# Iterate through each column of the dataframe and check for white spaces
for col in df.columns:
    # Count the number of white spaces in the column
    num_spaces = sum(df[col].astype(str).apply(lambda x: x.isspace()))

    # Display the results
    print(f"Column '{col}' has {num_spaces} white spaces.")
# Out:
# Column 'Interest' has 0 white spaces.
# Column 'Unemp_rate' has 0 white spaces.
# Column 'Income' has 0 white spaces.
# Column 'Const_units' has 0 white spaces.
# Column 'Const_price' has 0 white spaces.
# Column 'empl_population' has 0 white spaces.
# Column 'population' has 0 white spaces.
# Column 'Units_Authoriz' has 0 white spaces.
# Column 'CSUSHPISA' has 0 white spaces.
# Column 'CPIAUCNS' has 0 white spaces.
# Column 'sale_price' has 0 white spaces.
# Column 'GDP' has 0 white spaces.
# Column 'households' has 0 white spaces.
# Column 'Subsidies' has 0 white spaces.
# Column 'Month' has 0 white spaces.
# Column 'Year' has 0 white spaces.
# Column 'Day' has 0 white spaces.

# %% [markdown]
# Observation:- dataset doesnt contain any white space

# %%
#checking number of unique values
df.nunique()
# Out:
# Interest           115
# Unemp_rate          70
# Income             241
# Const_units        219
# Const_price        205
# empl_population     57
# population         241
# Units_Authoriz     228
# CSUSHPISA          241
# CPIAUCNS           237
# sale_price          80
# GDP                 81
# households          21
# Subsidies           21
# Month               12
# Year                21
# Day                  1
# dtype: int64

# %% [markdown]
# ##### Visualization¶

# %% [markdown]
# ###### univariant visualization

# %%
# Checking how the data has been distriubted in each column

plt.figure(figsize=(10,10),facecolor='white')
plotnumber=1
for i in df.columns:
    if plotnumber<=16:
        ax=plt.subplot(4,4,plotnumber)
        sns.distplot(df[i],color="b")
        plt.xlabel(i,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Observation: data available in Interest', 'Unemp_rate', 'Income', 'Const_units', 'Const_price',
#        'empl_population', 'population', 'Units_Authoriz', 'CSUSHPISA',
#        'CPIAUCNS', 'sale_price', 'GDP',  'Subsidies' is skewed

# %%
fig, (ax1, ax2,ax3,ax4) = plt.subplots(4, 1, figsize=(15, 8))

sns.barplot(data=df, x='Year', y='Interest', color='g', ax=ax1).set(title='Fixed interest rate of years')
ax1.grid(True)

sns.lineplot(data=df, x='Year', y='Unemp_rate', marker='o', color='b', ax=ax2).set(title='unemployee rate Over The Year')
ax2.grid(True)

sns.lineplot(data=df, x='Year', y='Income', marker='o', color='r', ax=ax3).set(title='income Over The Year')
ax3.grid(True)

sns.lineplot(data=df, x='Year', y='Const_units', marker='o', color='g', ax=ax4).set(title='Const_units Over The Year')
ax4.grid(True)

fig.tight_layout()
plt.show()

# %% [markdown]
# Observation:
#
# 1. Despite low-interest rates during the years 2008 to 2021 correlating with a relatively low Home Price Index (HPI), the scenario changed after in 2021. Even with higher interest rates, the HPI increased
#
# 2. Income has been increasing steadily over the years, with a few minor dips. In 2003, the average annual income was around $18000. By 2022, it  had  increased  to over $26,000. This represents an increase of over 40% over the past two decades.
#
# 3. The unemployment rate has fluctuated over the years, but it has generally been trending downwards. In 2003, the unemployment rate was over 6%. By 2022, it had fallen to below 4%. This represents a significant improvement in the labor market over the past two decades.
#
# 4. The construction unit line shows the value of a constant unit of currency over time. This is useful for comparing the purchasing power of income over time. For example, in 2003, $18,000 could buy more goods and services than $18,000 can today. This is because inflation has caused the value of currency to decrease over time.

# %%
fig, (ax1, ax2,ax3,ax4) = plt.subplots(4, 1, figsize=(15, 8))

sns.barplot(data=df, x='Year', y='Const_price', color='g', ax=ax1).set(title='Const_price over the years')
ax1.grid(True)

sns.lineplot(data=df, x='Year', y='empl_population', marker='o', color='b', ax=ax2).set(title='empl_population Over The Year')
ax2.grid(True)

sns.lineplot(data=df, x='Year', y='population', marker='o', color='r', ax=ax3).set(title='population Over The Year')
ax3.grid(True)

sns.lineplot(data=df, x='Year', y='Units_Authoriz', marker='o', color='g', ax=ax4).set(title='Units_Authoriz Over The Year')
ax4.grid(True)

fig.tight_layout()
plt.show()

# %% [markdown]
# Observation:
#
# 1. The number of units manufactured has increased steadily over the years, with a few minor dips.
#
# 2. The "Units Authoriz" line shows the largest increase in manufacturing output. This suggests that the number of units authorized for production has been growing faster than the population or the number of units produced at a constant price.
#
# 3. The "population" line shows that the population has also been growing over the years, but at a slower rate than the number of units manufactured.
#
# 4. The "Const price" line shows the value of a constant unit of currency over time. This is useful for comparing the purchasing power of manufacturing output over time. For example, in 2003, 1,000 units manufactured at a constant price could buy more goods and services than 1,000 units manufactured at a constant price in 2023. This is because inflation has caused the value of currency to decrease over time.

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 8))

sns.barplot(data=df, x='Year', y='CSUSHPISA', color='g', ax=ax1).set(title='house price index of years')
ax1.grid(True)

sns.lineplot(data=df, x='Year', y='CPIAUCNS', marker='o', color='b', ax=ax2).set(title='CPI index Over The Year')
ax2.grid(True)

fig.tight_layout()
plt.show()

# %% [markdown]
# Observation:
# 1. House prices have increased steadily over the past two decades, with a few minor dips. The index has increased from 100 in 2003 to over 300 in 2023. This represents a more than threefold increase in house prices over the past two decades. The largest increase in house prices occurred between 2003 and 2007. This was a period of economic prosperity, with low interest rates and high demand for housing.The housing bubble burst in 2008, leading to a sharp decline in house prices. However, house prices began to recover in 2012 and have continued to rise since then.
#
# 2. The CPI index is a measure of inflation. As you can see, the CPI index has also been increasing over the past two decades. However, the house price index has increased at a faster rate than the CPI index. This means that house prices have become less affordable over time.

# %% [markdown]
# ###### Bivarient analysis with target variable CSUSHPISA(price index)

# %%
# Set up a 2x2 grid for subplots
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 8))

# Scatter plot
sns.scatterplot(x='Interest', y='CSUSHPISA', data=df, ax=axes[0, 0],color='green')
axes[0, 0].set_title('CSUSHPISA vs Interest')

# Line plot
sns.lineplot(x='Unemp_rate', y='CSUSHPISA', data=df, ax=axes[0, 1],color='red')
axes[0, 1].set_title('CSUSHPISA vs Unemp_rate')

# Regression plot
sns.regplot(x='Income', y='CSUSHPISA', data=df, ax=axes[1, 0],color='orange')
axes[1, 0].set_title('CSUSHPISA vs Income')

# line plot
sns.lineplot(x='Const_units', y='CSUSHPISA', data=df, ax=axes[1, 1],color='blue')
axes[1, 1].set_title('CSUSHPISA vs Const_units')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %%
# Set up a 2x2 grid for subplots
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 8))

# Scatter plot
sns.scatterplot(x='Const_price', y='CSUSHPISA', data=df, ax=axes[0, 0],color='green')
axes[0, 0].set_title('CSUSHPISA vs Const_price')

# Line plot
sns.lineplot(x='empl_population', y='CSUSHPISA', data=df, ax=axes[0, 1],color='red')
axes[0, 1].set_title('CSUSHPISA vs empl_population')

# Regression plot
sns.regplot(x='population', y='CSUSHPISA', data=df, ax=axes[1, 0],color='orange')
axes[1, 0].set_title('CSUSHPISA vs population')

# line plot
sns.lineplot(x='Units_Authoriz', y='CSUSHPISA', data=df, ax=axes[1, 1],color='blue')
axes[1, 1].set_title('CSUSHPISA vs Units_Authoriz')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# ###### multivariant analysis

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# ###### statistical summary

# %%
# statistical summary of numerical columns
df.describe()
# Out:
#          Interest  Unemp_rate        Income  Const_units  Const_price  \
# count  241.000000  241.000000    241.000000   241.000000   241.000000
# mean     1.440498    5.917842  13703.870954  1196.066390   219.568905
# std      1.719548    2.094291   1865.007223   417.771044    48.230459
# min      0.050000    3.100000  10940.800000   520.000000   149.000000
# 25%      0.120000    4.400000  12194.800000   839.000000   189.200000
# 50%      0.400000    5.200000  13112.500000  1182.000000   209.800000
# 75%      2.280000    7.300000  15238.600000  1405.000000   233.800000
# max      5.330000   14.400000  20422.600000  2245.000000   353.015000
#
#        empl_population     population  Units_Authoriz   CSUSHPISA    CPIAUCNS  \
# count       241.000000     241.000000      241.000000  241.000000  241.000000
# mean         63.890871  316392.186722     1296.858921  186.860714  234.327145
# std           1.595488   13416.739200      469.316938   46.242191   29.439093
# min          60.000000  291222.000000      513.000000  136.294000  184.300000
# 25%          62.700000  305158.000000      980.000000  151.338000  213.528000
# 50%          63.400000  317635.000000     1291.000000  175.739000  233.546000
# 75%          65.700000  329216.000000     1622.000000  204.349000  252.006000
# max          66.900000  335675.000000     2263.000000  311.175000  307.789000
#
#             Month         Year    Day
# count  241.000000   241.000000  241.0
# mean     6.510373  2013.207469    1.0
# std      3.455807     5.820090    0.0
# min      1.000000  2003.000000    1.0
# 25%      4.000000  2008.000000    1.0
# 50%      7.000000  2013.000000    1.0
# 75%      9.000000  2018.000000    1.0
# max     12.000000  2023.000000    1.0

# %% [markdown]
# Observation:
# 1. count is same for all features
# 2. detection of outlier is possible in constrution price, income, unit authorised

# %%
#correlation
df.corr()
# Out:
#                  Interest  Unemp_rate    Income  Const_units  Const_price  \
# Interest         1.000000   -0.543019 -0.133384     0.687239    -0.003925
# Unemp_rate      -0.543019    1.000000 -0.253441    -0.582218    -0.339108
# Income          -0.133384   -0.253441  1.000000    -0.086402     0.854820
# Const_units      0.687239   -0.582218 -0.086402     1.000000    -0.035968
# Const_price     -0.003925   -0.339108  0.854820    -0.035968     1.000000
# empl_population  0.434711    0.087387 -0.864680     0.337164    -0.711265
# population      -0.256397   -0.232558  0.940326    -0.303188     0.825048
# Units_Authoriz   0.459829   -0.607481  0.075441     0.907892     0.103791
# CSUSHPISA        0.306938   -0.542496  0.797618     0.342939     0.909421
# CPIAUCNS        -0.078221   -0.298141  0.924773    -0.174599     0.952922
# Month            0.002811   -0.095334 -0.029216     0.003093    -0.021890
# Year            -0.200855   -0.263590  0.960554    -0.225783     0.876803
# Day                   NaN         NaN       NaN          NaN          NaN
#
#                  empl_population  population  Units_Authoriz  CSUSHPISA  \
# Interest                0.434711   -0.256397        0.459829   0.306938
# Unemp_rate              0.087387   -0.232558       -0.607481  -0.542496
# Income                 -0.864680    0.940326        0.075441   0.797618
# Const_units             0.337164   -0.303188        0.907892   0.342939
# Const_price            -0.711265    0.825048        0.103791   0.909421
# empl_population         1.000000   -0.921785        0.088065  -0.546214
# population             -0.921785    1.000000       -0.119451   0.684876
# Units_Authoriz          0.088065   -0.119451        1.000000   0.421052
# CSUSHPISA              -0.546214    0.684876        0.421052   1.000000
# CPIAUCNS               -0.826533    0.941643       -0.024093   0.839883
# Month                   0.051329   -0.009947        0.009910  -0.010972
# Year                   -0.910003    0.991750       -0.044003   0.758478
# Day                          NaN         NaN             NaN        NaN
#
#                  CPIAUCNS     Month      Year  Day
# Interest        -0.078221  0.002811 -0.200855  NaN
# Unemp_rate      -0.298141 -0.095334 -0.263590  NaN
# Income           0.924773 -0.029216  0.960554  NaN
# Const_units     -0.174599  0.003093 -0.225783  NaN
# Const_price      0.952922 -0.021890  0.876803  NaN
# empl_population -0.826533  0.051329 -0.910003  NaN
# population       0.941643 -0.009947  0.991750  NaN
# Units_Authoriz  -0.024093  0.009910 -0.044003  NaN
# CSUSHPISA        0.839883 -0.010972  0.758478  NaN
# CPIAUCNS         1.000000 -0.014689  0.967452  NaN
# Month           -0.014689  1.000000 -0.061220  NaN
# Year             0.967452 -0.061220  1.000000  NaN
# Day                   NaN       NaN       NaN  NaN

# %%
# visualize the correlation
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),linewidths=0.1,fmt='0.2f',annot=True)
# Out:
# <AxesSubplot:>

# %%
# correlation of column with target column votes
df.corr()["CSUSHPISA"].sort_values()
# Out:
# empl_population   -0.546214
# Unemp_rate        -0.542496
# Month             -0.010972
# Interest           0.306938
# Const_units        0.342939
# Units_Authoriz     0.421052
# population         0.684876
# Year               0.758478
# Income             0.797618
# CPIAUCNS           0.839883
# Const_price        0.909421
# CSUSHPISA          1.000000
# Day                     NaN
# Name: CSUSHPISA, dtype: float64

# %% [markdown]
# Observation:
# US house price index is
# 1. positively corelated with construction price, CPI index, Income, year, population
# 2. negatively corelated with employee population, unemployeement rate

# %%
#plotting corelation
plt.figure(figsize=(22,7))
df.corr()['CSUSHPISA'].sort_values(ascending=False).drop(['CSUSHPISA']).plot(kind='bar')
plt.xlabel('Values',fontsize=14)
plt.ylabel('CSUSHPISA',fontsize=14)
plt.title('corelation',fontsize=16)
plt.show()

# %% [markdown]
# ###### Outlier detection

# %%
plt.figure(figsize=(20, 25), facecolor='white')
plotnumber = 1

for column in df.columns:
    if plotnumber <= 20 and pd.api.types.is_numeric_dtype(df[column]):
        ax = plt.subplot(5, 4, plotnumber)
        sns.boxplot(df[column])
        plt.xlabel(column, fontsize=20)
        plotnumber += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# Observation:
# Outlier detected in Unemployment rate, income, construction price and price index

# %%
# Outlier removing
df.shape
# Out:
# (241, 17)

# %%
#dropping irrevant column
df.drop(['Month','Day'],axis=1,inplace=True)

# %%
# Outlier removing
df.shape
# Out:
# (241, 15)

# %%
df.columns
# Out:
# Index(['Interest', 'Unemp_rate', 'Income', 'Const_units', 'Const_price',
#        'empl_population', 'population', 'Units_Authoriz', 'CSUSHPISA',
#        'CPIAUCNS', 'sale_price', 'GDP', 'households', 'Subsidies', 'Year'],
#       dtype='object')

# %%
from scipy.stats import zscore

columns = [ 'Unemp_rate', 'Income', 'Const_price',]
z = np.abs(zscore(df[columns]))
z
# Out:
#      Unemp_rate    Income  Const_price
# 0      0.056385  1.484617     1.466206
# 1      0.152082  1.462319     1.453739
# 2      0.152082  1.426803     1.441273
# 3      0.247778  1.422074     1.451662
# 4      0.182856  1.425298     1.445429
# ..          ...       ...          ...
# 236    1.204743  1.673512     2.449686
# 237    1.013350  1.668676     2.446839
# 238    1.013350  1.661906     2.389495
# 239    0.965502  1.663410     2.377112
# 240    1.109046  1.666150     2.340628
#
# [241 rows x 3 columns]

# %%
threshold=3
np.where(z>3)
# Out:
# (array([199, 200, 210], dtype=int64), array([0, 0, 1], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#      Interest  Unemp_rate   Income  Const_units  Const_price  empl_population  \
# 0        1.01         5.8  10940.8       1719.0      149.000             65.9
# 1        1.01         5.6  10982.3       1728.0      149.600             66.1
# 2        1.00         5.6  11048.4       1692.0      150.200             66.1
# 3        0.98         5.4  11057.2       1716.0      149.700             65.8
# 4        1.00         6.3  11051.2       1709.0      150.000             65.7
# ..        ...         ...      ...          ...          ...              ...
# 236      5.06         3.4  16818.5       1534.0      337.473             62.5
# 237      5.08         3.8  16809.5       1492.0      337.336             62.9
# 238      5.12         3.8  16796.9       1334.0      334.576             63.1
# 239      5.33         3.9  16799.7       1370.0      333.980             62.9
# 240      5.33         3.6  16804.8       1478.0      332.224             62.7
#
#      population  Units_Authoriz  CSUSHPISA  CPIAUCNS sale_price      GDP  \
# 0      291222.0          1961.0    136.294   185.200      19750    51512
# 1      291463.0          2012.0    137.531   185.000   198800.0  51986.0
# 2      291677.0          1918.0    138.794   184.500   198800.0  51986.0
# 3      291868.0          1987.0    140.179   184.300   198800.0  51986.0
# 4      292046.0          1952.0    141.646   185.200   212700.0  52179.0
# ..          ...             ...        ...       ...        ...      ...
# 236    335013.0          1496.0    302.566   304.127   418500.0  66341.0
# 237    335163.0          1441.0    304.593   305.109   418500.0  66341.0
# 238    335329.0          1443.0    306.767   305.691   431000.0  67083.0
# 239    335501.0          1541.0    309.155   307.026   431000.0  67083.0
# 240    335675.0          1471.0    311.175   307.789   431000.0  67083.0
#
#     households Subsidies  Year
# 0     111278.0     25.93  2003
# 1     111278.0     25.93  2003
# 2     111278.0     25.93  2003
# 3     111278.0     25.93  2003
# 4     112000.0    27.201  2004
# ..         ...       ...   ...
# 236   131434.0    50.299  2023
# 237   131434.0    50.299  2023
# 238   131434.0    50.299  2023
# 239   131434.0    50.299  2023
# 240   131434.0    50.299  2023
#
# [238 rows x 15 columns]

# %%
df_new.shape
# Out:
# (238, 15)

# %%
#data loss in percentage
Data_loss =((df.shape[0]-df_new.shape[0])/df.shape[0])*100
Data_loss
# Out:
# 1.2448132780082988

# %% [markdown]
# Data loss is in acceptable range

# %% [markdown]
# #### Model building

# %%
x=df.drop("CSUSHPISA",axis=1)

# %%
x.shape
# Out:
# (241, 14)

# %%
y = df["CSUSHPISA"]

# %%
y.shape
# Out:
# (241,)

# %%
#scalling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#      Interest  Unemp_rate    Income  Const_units  Const_price  \
# 0   -0.250876   -0.056385 -1.484617     1.254328    -1.466206
# 1   -0.250876   -0.152082 -1.462319     1.275916    -1.453739
# 2   -0.256704   -0.152082 -1.426803     1.189565    -1.441273
# 3   -0.268359   -0.247778 -1.422074     1.247132    -1.451662
# 4   -0.256704    0.182856 -1.425298     1.230342    -1.445429
# ..        ...         ...       ...          ...          ...
# 236  2.109296   -1.204743  1.673512     0.810580     2.449686
# 237  2.120951   -1.013350  1.668676     0.709837     2.446839
# 238  2.144262   -1.013350  1.661906     0.330853     2.389495
# 239  2.266641   -0.965502  1.663410     0.417204     2.377112
# 240  2.266641   -1.109046  1.666150     0.676256     2.340628
#
#      empl_population  population  Units_Authoriz  CPIAUCNS  sale_price  \
# 0           1.261877   -1.879933        1.418068 -1.672245   -3.761135
# 1           1.387491   -1.861933        1.526963 -1.679053   -1.240390
# 2           1.387491   -1.845950        1.326255 -1.696073   -1.240390
# 3           1.199070   -1.831684        1.473583 -1.702881   -1.240390
# 4           1.136263   -1.818389        1.398851 -1.672245   -1.044699
# ..               ...         ...             ...       ...         ...
# 236        -0.873567    1.390768        0.425204  2.375926    1.852644
# 237        -0.622338    1.401971        0.307769  2.409353    1.852644
# 238        -0.496724    1.414369        0.312039  2.429164    2.028625
# 239        -0.622338    1.427216        0.521288  2.474606    2.028625
# 240        -0.747953    1.440212        0.371824  2.500578    2.028625
#
#           GDP  households  Subsidies      Year
# 0   -1.538695   -1.771754  -1.491914 -1.757484
# 1   -1.424160   -1.771754  -1.491914 -1.757484
# 2   -1.424160   -1.771754  -1.491914 -1.757484
# 3   -1.424160   -1.771754  -1.491914 -1.757484
# 4   -1.377525   -1.653061  -1.294826 -1.585307
# ..        ...         ...        ...       ...
# 236  2.044492    1.541800   2.286873  1.686041
# 237  2.044492    1.541800   2.286873  1.686041
# 238  2.223784    1.541800   2.286873  1.686041
# 239  2.223784    1.541800   2.286873  1.686041
# 240  2.223784    1.541800   2.286873  1.686041
#
# [241 rows x 14 columns]

# %%
# importing necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ###### 1.Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
#finding best random state
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.2, random_state =i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    acc=r2_score(y_test,pred_test)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is ",maxAccu," on Random_state ",maxRS)
# Out:
# Best accuracy is  0.9937571303151767  on Random_state  146

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=146)

# %%
# checking r2 score for linear regression
lr.fit(x_train,y_train)

# prediction
pred_test=lr.predict(x_test)
print('R2_score/test_accuracy:',r2_score(y_test,pred_test))

# mean Absolute error (MAE)
print('Mean Absolute Error:',mean_absolute_error(y_test, pred_test))

# mean Squared error (MSE)
print('Mean Squared Error:',mean_squared_error(y_test, pred_test))

# root mean Squared error (RMSE)
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test, pred_test)))
# Out:
# R2_score/test_accuracy: 0.9937571303151767
# Mean Absolute Error: 3.6169255016602366
# Mean Squared Error: 18.299251017637914
# Root Mean Squared Error: 4.277762384429261

# %%
# naming instance
test_accuracy=r2_score(y_test,pred_test)

# %%
# checking cross validation score for Linear Regression
print("Cross Validation Score for Linear Regression:",cross_val_score(lr,x,y,cv=7).mean())
print('R2_score/test_accuracy for Linear Regression:',r2_score(y_test,pred_test))
# visualizing the predicted values
sns.regplot(y_test,pred_test,color="r")
plt.show()
# Out:
# Cross Validation Score for Linear Regression: -0.601439592122346
# R2_score/test_accuracy for Linear Regression: 0.9937571303151767

# %% [markdown]
# ###### Regularization

# %%
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor
from sklearn.linear_model import Lasso, Ridge
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import BaggingRegressor

# %% [markdown]
# ###### Lasso Regressor

# %%
from sklearn.model_selection import GridSearchCV
# checking best alpha value
parameters={'alpha':[1e-15,1e-10, 1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,50,55,100]}
lasso=Lasso()
clf=GridSearchCV(lasso,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1}

# %%
# checking r2score for Lasso Regressor
laso=Lasso(alpha=1)

# predictions
lasso.fit(x_train,y_train)
lasso.score(x_train,y_train)

# prediction
pred_test=lasso.predict(x_test)
print('R2_score/test_accuracy for lasso regression:',r2_score(y_test,pred_test))

# mean Absolute error (MAE)
print('Mean Absolute Error for lasso regression:',mean_absolute_error(y_test, pred_test))

# mean Squared error (MSE)
print('Mean Squared Error for lasso regression:',mean_squared_error(y_test, pred_test))

# root mean Squared error (RMSE)
print("Root Mean Squared Error for lasso regression:",np.sqrt(mean_squared_error(y_test, pred_test)))


# checking cv score for lasso regression
print("Cross Validation Score:",cross_val_score(lasso,x,y,cv=7).mean())

# Visualizing the predicted values
sns.regplot(y_test,pred_test,color="g")
plt.show()
# Out:
# R2_score/test_accuracy for lasso regression: 0.9917158215040528
# Mean Absolute Error for lasso regression: 4.24904104483778
# Mean Squared Error for lasso regression: 24.282784909123983
# Root Mean Squared Error for lasso regression: 4.927756579735243
# Cross Validation Score: -0.8797668989113243

# %% [markdown]
# ###### Ridge Regressor

# %%
# checking best alpha value
paramsRidge = {'alpha':[1e-15,1e-10, 1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,50,55,100]}
ridge=Ridge()
clf=GridSearchCV(ridge,paramsRidge)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 5}

# %%
# checking r2score for Ridge Regressor
ridge=Ridge(alpha=50)

# predictions
ridge.fit(x_train,y_train)
ridge.score(x_train,y_train)

# prediction
pred_test=ridge.predict(x_test)
print('R2_score/test_accuracy for Ridge regression:',r2_score(y_test,pred_test))

# mean Absolute error (MAE)
print('Mean Absolute Error for Ridge regression:',mean_absolute_error(y_test, pred_test))

# mean Squared error (MSE)
print('Mean Squared Error for Ridge regression:',mean_squared_error(y_test, pred_test))

# root mean Squared error (RMSE)
print("Root Mean Squared Error for Ridge regression:",np.sqrt(mean_squared_error(y_test, pred_test)))


# checking cv score for Ridge regression
print("Cross Validation Score:",cross_val_score(ridge,x,y,cv=7).mean())

# Visualizing the predicted values
sns.regplot(y_test,pred_test,color="r")
plt.show()
# Out:
# R2_score/test_accuracy for Ridge regression: 0.9797508677623676
# Mean Absolute Error for Ridge regression: 6.746119426798016
# Mean Squared Error for Ridge regression: 59.3547474820092
# Root Mean Squared Error for Ridge regression: 7.704203234729027
# Cross Validation Score: -0.8684251134256813

# %% [markdown]
# ###### Ensemble Techniques

# %% [markdown]
# ###### Random Forest Regressor

# %%
# checking r2score for Random Forest Regressor
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)

# prediction
pred_test=RFR.predict(x_test)
print('R2_score/test_accuracy for Random Forest regression:',r2_score(y_test,pred_test))

# mean Absolute error (MAE)
print('Mean Absolute Error for Random Forest regression:',mean_absolute_error(y_test, pred_test))

# mean Squared error (MSE)
print('Mean Squared Error for Random Forest regression:',mean_squared_error(y_test, pred_test))

# root mean Squared error (RMSE)
print("Root Mean Squared Error for Random Forest regression:",np.sqrt(mean_squared_error(y_test, pred_test)))

# checking cv score for Random Forest regression
print("Cross Validation Score:",cross_val_score(RFR,x,y,cv=7).mean())

# Visualizing the predicted values
sns.regplot(y_test,pred_test,color="g")
plt.show()
# Out:
# R2_score/test_accuracy for Random Forest regression: 0.9991653305015382
# Mean Absolute Error for Random Forest regression: 1.1594253061225144
# Mean Squared Error for Random Forest regression: 2.4466034756818122
# Root Mean Squared Error for Random Forest regression: 1.5641622280575032
# Cross Validation Score: -1.7188259626733784

# %% [markdown]
# ###### Extra Trees Regressor

# %%
# checking r2score for Extra Trees Regressor
XT=ExtraTreesRegressor()
XT.fit(x_train,y_train)

# prediction
pred_test=XT.predict(x_test)
print('R2_score/test_accuracy for Extra Trees regression:',r2_score(y_test,pred_test))

# mean Absolute error (MAE)
print('Mean Absolute Error for Extra Trees regression:',mean_absolute_error(y_test, pred_test))

# mean Squared error (MSE)
print('Mean Squared Error for Extra Trees regression:',mean_squared_error(y_test, pred_test))

# root mean Squared error (RMSE)
print("Root Mean Squared Error for Extra Trees regression:",np.sqrt(mean_squared_error(y_test, pred_test)))


# checking cv score for Extra Trees regression
print("Cross Validation Score:",cross_val_score(XT,x,y,cv=7).mean())

# Visualizing the predicted values
sns.regplot(y_test,pred_test,color="r")
plt.show()
# Out:
# R2_score/test_accuracy for Extra Trees regression: 0.9996889897759096
# Mean Absolute Error for Extra Trees regression: 0.7647346938776068
# Mean Squared Error for Extra Trees regression: 0.911640711245002
# Root Mean Squared Error for Extra Trees regression: 0.9547987805003744
# Cross Validation Score: -0.7064596740846257

# %% [markdown]
# ###### Gradient Boosting Regressor

# %%
# checking r2score for GradientBoosting Regressor
GB=GradientBoostingRegressor()
GB.fit(x_train,y_train)

# prediction
pred_test=GB.predict(x_test)
print('R2_score/test_accuracy for GradientBoosting regression:',r2_score(y_test,pred_test))

# mean Absolute error (MAE)
print('Mean Absolute Error for GradientBoosting regression:',mean_absolute_error(y_test, pred_test))

# mean Squared error (MSE)
print('Mean Squared Error for GradientBoosting regression:',mean_squared_error(y_test, pred_test))

# root mean Squared error (RMSE)
print("Root Mean Squared Error for GradientBoosting regression:",np.sqrt(mean_squared_error(y_test, pred_test)))

# checking cv score for Gradient Boosting regression
print("Cross Validation Score:",cross_val_score(GB,x,y,cv=7).mean())

# Visualizing the predicted values
sns.regplot(y_test,pred_test,color="g")
plt.show()
# Out:
# R2_score/test_accuracy for GradientBoosting regression: 0.9987949570701071
# Mean Absolute Error for GradientBoosting regression: 1.5044491254229553
# Mean Squared Error for GradientBoosting regression: 3.532251059916788
# Root Mean Squared Error for GradientBoosting regression: 1.8794283864826529
# Cross Validation Score: -0.8230317509377514

# %% [markdown]
# ###### Bagging Regressor

# %%
# checking r2score for Bagging Regressor
BR=BaggingRegressor()
BR.fit(x_train,y_train)

# prediction
pred_test=BR.predict(x_test)
print('R2_score/test_accuracy for Bagging regression:',r2_score(y_test,pred_test))

# mean Absolute error (MAE)
print('Mean Absolute Error for Bagging regression:',mean_absolute_error(y_test, pred_test))

# mean Squared error (MSE)
print('Mean Squared Error for Bagging regression:',mean_squared_error(y_test, pred_test))

# root mean Squared error (RMSE)
print("Root Mean Squared Error for Bagging regression:",np.sqrt(mean_squared_error(y_test, pred_test)))

# checking cv score for Bagging regression
print("Cross Validation Score:",cross_val_score(BR,x,y,cv=7).mean())

# Visualizing the predicted values
sns.regplot(y_test,pred_test,color="r")
plt.show()
# Out:
# R2_score/test_accuracy for Bagging regression: 0.9985562378623912
# Mean Absolute Error for Bagging regression: 1.4881979591836743
# Mean Squared Error for Bagging regression: 4.231990590816334
# Root Mean Squared Error for Bagging regression: 2.0571802523882865
# Cross Validation Score: -1.3848525693145284

# %% [markdown]
# Observation:
#
# 1. linear regration
#
#    R2_score/test_accuracy: 0.9937571303151767
#
#    Mean Absolute Error: 3.6169255016602366
#
# 2. lasso regrassor
#
#    R2_score/test_accuracy for lasso regression: 0.9917158215040528
#
#    Mean Absolute Error for lasso regression: 4.24904104483778
#
# 3. Ridge Regressor
#
#    R2_score/test_accuracy for Ridge regression: 0.9797508677623676
#
#    Mean Absolute Error for Ridge regression: 6.746119426798016
#
#
# 4. Random Forest Regressor
#
#    R2_score/test_accuracy for Random Forest regression: 0.9988933725863773
#
#    Mean Absolute Error for Random Forest regression: 1.2683916326531375
#
#
# 5. Extra Trees Regressor
#
#    R2_score/test_accuracy for Extra Trees regression: 0.9996135831233464
#
#    Mean Absolute Error for Extra Trees regression: 0.7647346938776068
#
#
# 6. GradientBoosting Regressor
#
#    R2_score/test_accuracy for GradientBoosting regression: 0.9989991498449123
#
#    Mean Absolute Error for GradientBoosting regression: 1.5044491254229553
#
#
# 7. Bagging Regressor
#
#    R2_score/test_accuracy for Bagging regression: 0.9990650613686026
#
#    Mean Absolute Error for Bagging regression: 1.4881979591836743

# %% [markdown]
# ###### From above observation I choose Extra Trees regression as it have high accuracy and low MAE

# %% [markdown]
# ###### Hyperparameter tuning

# %%
# Importing Libraries
from sklearn.model_selection import GridSearchCV

# %%
#Define the hyperparameter grid to search
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# %%
#Create the Extra TreesingRegressor model
ET = ExtraTreesRegressor()

# Perform grid search using the defined parameter grid
grid_search = GridSearchCV(ET, param_grid, cv=7)

# %%
#Fit the grid search to the training data
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=7, estimator=ExtraTreesRegressor(),
#              param_grid={'max_depth': [None, 10, 20],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]})

# %%
# Get the best hyperparameters and best model
best_params = grid_search.best_params_
print("best_params:",best_params)
best_model = grid_search.best_estimator_
print("best_model:",best_model)
# Out:
# best_params: {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# best_model: ExtraTreesRegressor(n_estimators=200)

# %%
# Checking score with best parameter
final_model=ExtraTreesRegressor(min_samples_leaf=1, max_depth=None, n_estimators=200,min_samples_split= 2 )
final_model.fit(x_train,y_train)
predfinal=final_model.predict(x_test)
print('Final Accuracy is with ExtraTrees Regressor is  = ',r2_score(y_test,predfinal))
# Out:
# Final Accuracy is with ExtraTrees Regressor is  =  0.9996552411678317

# %% [markdown]
# ###### After hyperparameter tuning accuracy is 99.96%

# %% [markdown]
# ###### Saving the Model

# %%
#importing library
import joblib
#saving the model
joblib.dump(ET,'US_house_price.pkl')
# Out:
# ['US_house_price.pkl']

# %% [markdown]
# ###### prediction

# %%
# Predict house price of 2024
data = {'Interest' : 5.33,'Unemp_rate' : 3.5,'Income' : 16985.4,'Const_units' : 1475,'Const_price' : 330,'empl_population' : 62.5,'population ': 335705,'Units_Authoriz':1472, 'CPIAUCNS':310.1,'sale_price':431000.0,'GDP':67083.0, 'households':131434.0, 'Subsidies':50.299, 'Year': 2024 }
index=[1]
df_2024 = pd.DataFrame(data,index)
df_2024
# Out:
#    Interest  Unemp_rate   Income  Const_units  Const_price  empl_population  \
# 1      5.33         3.5  16985.4         1475          330             62.5
#
#    population   Units_Authoriz  CPIAUCNS  sale_price      GDP  households  \
# 1       335705            1472     310.1    431000.0  67083.0    131434.0
#
#    Subsidies  Year
# 1     50.299  2024

# %%
predicted_price = final_model.predict(df_2024)

print(f"Predicted House Price for 2024: {predicted_price}")
# Out:
# Predicted House Price for 2024: [299.719275]

# %% [markdown]
# #### Conclusion

# %% [markdown]
# The US Housing Market Analysis underscores the multifaceted nature of factors influencing home prices.

# %% [markdown]
# ###### The Extra Trees Regressor model demonstrates exceptional performance, achieving an accuracy of 99.96% in predicting house prices.

# %% [markdown]
#  This level of accuracy suggests that the model is capturing intricate relationships within the dataset, making it a powerful tool for predicting future house prices. It outperforms many traditional regression models, providing a robust solution for real estate price forecasting. However, it's crucial to conduct thorough validation and testing to ensure the model's generalization to new data and to consider potential overfitting, especially if the dataset used for training is limited in size. Overall, the high accuracy of the model signals its effectiveness and reliability in predicting house prices.
